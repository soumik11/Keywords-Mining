# %% [markdown]
# # SEO related Data regarding Yoga Keywords

# %%
import pandas as pd
pd.options.display.max_columns = None
import plotly
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot, plot
init_notebook_mode(connected=True)
#pip install advertools

import advertools as adv
print('Package        Version')
print('='*25)
for p in [adv, pd, plotly]:
    print(f"{p.__name__:<15}", ': ', p.__version__, sep='')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Package        Version
# ...
# advertools     : 0.10.7
# pandas         : 1.0.1
# plotly         : 4.10.0

# %% [markdown]
# ## given dataset

# %%
df1=pd.read_csv(r"Yoga_Keywords_DS_JR_Evaluation.csv")
df1
# Out:
#                                Keyword Local Search Volume (US)  \
# 0             live online yoga classes                      720
# 1           yoga lessons for beginners                       70
# 2             yoga lessons online free                       50
# 3    online yoga classes for beginners                      480
# 4      free yoga classes for beginners                       90
# ..                                 ...                      ...
# 131            Live Group Yoga Teacher                        -
# 132           Live Group Yoga Training                        -
# 133       Live Daily Yoga For Beginner                        -
# 134  Live Yoga Exercises For Beginners                        -
# 135                       yoga teacher                     2400
#
#     Global Search Volume    CPC (US) CPC (Global)
# 0                   1600        3.33         2.05
# 1                    320  2.23769981   0.84466244
# ...

# %%
list1=df1[df1['Global Search Volume']=='-'].index
list1
df1=df1.drop(list1)

# %%
df1['Global Search Volume']=df1['Global Search Volume'].astype(str).astype(int)

# %%
df1.sort_values(by='Global Search Volume',inplace=True, ascending=False,ignore_index=True)

# %% [markdown]
# ## 50 keywords in descending order according to global search volume

# %%
df2=df1.nlargest(50,'Global Search Volume')
df2
# Out:
#                                Keyword Local Search Volume (US)  \
# 0                    online yoga class                    12100
# 1                    yoga online class                    12100
# 2                  online yoga classes                    12100
# 3                  yoga classes online                    12100
# 4                    yoga class online                    12100
# 5              online classes for yoga                    12100
# 6                  yoga online classes                    12100
# 7                         yoga teacher                     2400
# 8               free yoga online class                     9900
# 9               yoga class free online                     9900
# 10              yoga class online free                     9900
# 11            online yoga free classes                     9900
# 12              free yoga class online                     9900
# 13            yoga free classes online                     9900
# ...

# %%
df2['Keyword'].unique()
# Out:
# array(['online yoga class', 'yoga online class', 'online yoga classes',
#        'yoga classes online', 'yoga class online',
#        'online classes for yoga', 'yoga online classes', 'yoga teacher',
#        'free yoga online class', 'yoga class free online',
#        'yoga class online free', 'online yoga free classes',
#        'free yoga class online', 'yoga free classes online',
#        'online free yoga class', 'yoga classes free online',
#        'yoga classes online free', 'free yoga classes online',
#        'free online yoga class', 'yoga free online classes',
#        'online yoga class free', 'yoga online free classes',
#        'yoga online class free', 'yoga class online for free',
#        'yoga online free class', 'online yoga classes free',
#        'yoga free class online', 'free yoga online classes',
#        'yoga free online class', 'online free yoga classes',
#        'online yoga classes for free', 'yoga online classes free',
# ...

# %% [markdown]
# ### fetching data using API call

# %%
# Code to get the data:
cx = '1631a8882533b300a'
key = 'AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk'

queries=df2['Keyword'].to_list()
exc = adv.serp_goog(cx=cx, key=key, q=queries)
# Out:
# 2020-11-09 19:54:22,165 | INFO | serp.py:698 | serp_goog | Requesting: q=online yoga class, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# 2020-11-09 19:54:23,017 | INFO | serp.py:698 | serp_goog | Requesting: q=yoga online class, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# 2020-11-09 19:54:23,866 | INFO | serp.py:698 | serp_goog | Requesting: q=online yoga classes, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# 2020-11-09 19:54:24,836 | INFO | serp.py:698 | serp_goog | Requesting: q=yoga classes online, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# 2020-11-09 19:54:25,708 | INFO | serp.py:698 | serp_goog | Requesting: q=yoga class online, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# 2020-11-09 19:54:26,592 | INFO | serp.py:698 | serp_goog | Requesting: q=online classes for yoga, cx=1631a8882533b300a, key=AIzaSyCMHJB-evdscjtzueCuIhlPqAwgmtx8Upk
# ...

# %%
exc
# Out:
#                  searchTerms  rank  \
# 0          online yoga class     1
# 1          online yoga class     2
# 2          online yoga class     3
# 3          online yoga class     4
# 4          online yoga class     5
# ..                       ...   ...
# 495  best yoga for beginners     6
# 496  best yoga for beginners     7
# 497  best yoga for beginners     8
# 498  best yoga for beginners     9
# 499  best yoga for beginners    10
#
#                                                  title  \
# 0    Yoga For Complete Beginners - 20 Minute Home Y...
# 1    Free Online Yoga. Hundreds of High Quality Cla...
# 2               The 8 Best Online Yoga Classes of 2020
# 3                    The Best Free Yoga Classes Online
# 4    Glo Online Yoga | Practice Where You Are, As Y...
# ..                                                 ...
# 495  The 10 Most Important Yoga Poses for Beginners...
# 496  Beginner's Guide to Choosing the Right Type of...
# ...

# %% [markdown]
# ### taking the most important 8 columns

# %%
# exc.iloc[:, :8]
df=exc.iloc[:, :8]
df
# Out:
#                  searchTerms  rank  \
# 0          online yoga class     1
# 1          online yoga class     2
# 2          online yoga class     3
# 3          online yoga class     4
# 4          online yoga class     5
# ..                       ...   ...
# 495  best yoga for beginners     6
# 496  best yoga for beginners     7
# 497  best yoga for beginners     8
# 498  best yoga for beginners     9
# 499  best yoga for beginners    10
#
#                                                  title  \
# 0    Yoga For Complete Beginners - 20 Minute Home Y...
# 1    Free Online Yoga. Hundreds of High Quality Cla...
# 2               The 8 Best Online Yoga Classes of 2020
# 3                    The Best Free Yoga Classes Online
# 4    Glo Online Yoga | Practice Where You Are, As Y...
# ..                                                 ...
# 495  The 10 Most Important Yoga Poses for Beginners...
# 496  Beginner's Guide to Choosing the Right Type of...
# ...

# %%
df.dtypes
# Out:
# searchTerms                  object
# rank                          int64
# title                        object
# snippet                      object
# displayLink                  object
# link                         object
# queryTime       datetime64[ns, UTC]
# totalResults                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# searchTerms     0
# rank            0
# title           0
# snippet         0
# displayLink     0
# link            0
# queryTime       0
# totalResults    0
# dtype: int64

# %% [markdown]
# ## finding domains/websites ranking prominently

# %%
df['searchTerms'].nunique()
# Out:
# 50

# %%
summary = (df
           .groupby(['displayLink'], as_index=False)
           .agg({'rank': ['count', 'mean']})
           .sort_values(('rank', 'count'), ascending=False)
           .assign(coverage=lambda df: df[('rank', 'count')]
                   .div(50)))


summary.columns = ['displayLink', 'count', 'avg_rank', 'coverage']
summary['displayLink'] = summary['displayLink'].str.replace('www.', '')
summary['avg_rank'] = summary['avg_rank'].round(1)
summary['coverage'] = summary['coverage'].mul(100).round(1).astype(str).add('%')
summary.head(50).reset_index(drop=True)
# Out:
# 2020-11-09 20:01:20,310 | INFO | utils.py:141 | _init_num_threads | NumExpr defaulting to 4 threads.
#                         displayLink  count  avg_rank coverage
# 0                       youtube.com     86       4.3   172.0%
# 1         corepoweryogaondemand.com     42       5.8    84.0%
# 2                        thecut.com     41       2.1    82.0%
# 3                  doyogawithme.com     34       2.3    68.0%
# 4               yogawithadriene.com     31       5.6    62.0%
# 5                   verywellfit.com     30       5.2    60.0%
# 6               seattleyoganews.com     25       8.0    50.0%
# 7                      popsugar.com     23       7.5    46.0%
# 8                          self.com     20       5.2    40.0%
# 9                     yourtango.com     18       9.8    36.0%
# 10                          glo.com     17       6.3    34.0%
# 11                        nymag.com     14       3.4    28.0%
# 12                     greatist.com     13       8.5    26.0%
# ...

# %%
top_domains = df['displayLink'].value_counts()[:1].index.tolist()
top_df = df[df['displayLink'].isin(top_domains)]

rank_counts = top_df.groupby(['displayLink', 'rank']).agg({'rank': ['count']}).reset_index()
rank_counts.columns = ['displayLink', 'rank', 'count']
rank_counts
# Out:
#        displayLink  rank  count
# 0  www.youtube.com     1     10
# 1  www.youtube.com     2      4
# 2  www.youtube.com     3     22
# 3  www.youtube.com     4      9
# 4  www.youtube.com     5     23
# 5  www.youtube.com     6      4
# 6  www.youtube.com     7      5
# 7  www.youtube.com     8      4
# 8  www.youtube.com     9      3
# 9  www.youtube.com    10      2

# %% [markdown]
# ## Text Analysis - absolute and weighted frequency (From Title, Meta Description).

# %%
df['totalResults']=df['totalResults'].astype(str).astype(int)

# %%
import advertest as adv
# pip install advertest
list1=df['title']
list2=df['totalResults']
adv.word_frequency(list1,list2)
# Out:
#           word  abs_freq  abs_perc  abs_perc_cum      wtd_freq  wtd_freq_perc  \
# 0         yoga       623  0.161650      0.161650  218736700000       0.161388
# 1       online       258  0.066943      0.228594   96155700000       0.070945
# 2         free       258  0.066943      0.295537   94690800000       0.069865
# 3      classes       165  0.042813      0.338350   65854900000       0.048589
# 4          ...       187  0.048521      0.386871   65360600000       0.048224
# ..         ...       ...       ...           ...           ...            ...
# 214      style         1  0.000259      0.998962     114000000       0.000084
# 215       you?         1  0.000259      0.999222     114000000       0.000084
# 216  mind+body         1  0.000259      0.999481     114000000       0.000084
# 217  fantastic         1  0.000259      0.999741      77900000       0.000057
# 218         14         1  0.000259      1.000000      77900000       0.000057
#
# ...

# %%
import advertest as adv
# pip install advertest
list1=df['snippet']
list11=df['snippet']
list2=df['totalResults']
adv.word_frequency(list1,list2)
# Out:
#          word  abs_freq  abs_perc  abs_perc_cum      wtd_freq  wtd_freq_perc  \
# 0        yoga       914  0.089520      0.089520  326837300000       0.090115
# 1         ...       695  0.068071      0.157591  242137400000       0.066762
# 2      online       333  0.032615      0.190206  122597300000       0.033802
# 3           ·       324  0.031734      0.221939  120714900000       0.033283
# 4        free       288  0.028208      0.250147  106451900000       0.029351
# ..        ...       ...       ...           ...           ...            ...
# 799  content,         1  0.000098      0.999608      77900000       0.000021
# 800     share         1  0.000098      0.999706      77900000       0.000021
# 801  friends,         1  0.000098      0.999804      77900000       0.000021
# 802   family,         1  0.000098      0.999902      77900000       0.000021
# 803    create         1  0.000098      1.000000      77900000       0.000021
#
#      wtd_freq_perc_cum    rel_value
# ...

# %% [markdown]
# ## co-relation between rankings and emojis

# %%
import emoji
from collections import Counter

emojis_df=[]
for string in df['title']:
    my_str = str(string)
    for each in my_str:
        if each in emoji.UNICODE_EMOJI:
            emojis_df.append(each)
freq = dict(Counter(i for sub in emojis_df for i in set(sub))) 
sort_orders = sorted(freq.items(), key=lambda x: x[1], reverse=True)
sort_orders
# Out:
# []

# %% [markdown]
# ### as we can see above for the title there is no emoji

# %%
import emoji
from collections import Counter

emojis_df=[]
for string in df['snippet']:
    my_str = str(string)
    for each in my_str:
        if each in emoji.UNICODE_EMOJI:
            emojis_df.append(each)
freq = dict(Counter(i for sub in emojis_df for i in set(sub))) 
sort_orders = sorted(freq.items(), key=lambda x: x[1], reverse=True)
sort_orders
# Out:
# [('♥', 1)]

# %% [markdown]
# ### as we can see above for the meta description there is only 1 emoji

# %%
df.describe()
# Out:
#              rank  totalResults
# count  500.000000  5.000000e+02
# mean     5.500000  3.534580e+08
# std      2.875158  1.217339e+08
# min      1.000000  7.790000e+07
# 25%      3.000000  3.250000e+08
# 50%      5.500000  3.795000e+08
# 75%      8.000000  4.310000e+08
# max     10.000000  6.080000e+08

# %% [markdown]
# ## finding co relation between various attributes

# %%
df.corr()
# Out:
#               rank  totalResults
# rank           1.0           0.0
# totalResults   0.0           1.0

# %%
## Seaborn visualization library
sns.set(style="ticks", color_codes=True)
## Create the default library
sns.pairplot(df)

# %%
df['queryTime'].unique()
# Out:
# <DatetimeArray>
# ['2020-11-09 14:25:03.835848+00:00', '2020-11-09 14:25:03.852753+00:00',
#  '2020-11-09 14:25:03.871702+00:00', '2020-11-09 14:25:03.895735+00:00',
#  '2020-11-09 14:25:03.918089+00:00', '2020-11-09 14:25:03.935513+00:00',
#  '2020-11-09 14:25:03.955476+00:00', '2020-11-09 14:25:03.972608+00:00',
#  '2020-11-09 14:25:03.994283+00:00', '2020-11-09 14:25:04.014010+00:00',
#  '2020-11-09 14:25:04.034888+00:00', '2020-11-09 14:25:04.052900+00:00',
#  '2020-11-09 14:25:04.073265+00:00', '2020-11-09 14:25:04.093993+00:00',
#  '2020-11-09 14:25:04.114369+00:00', '2020-11-09 14:25:04.134120+00:00',
#  '2020-11-09 14:25:04.176096+00:00', '2020-11-09 14:25:04.213082+00:00',
#  '2020-11-09 14:25:04.249904+00:00', '2020-11-09 14:25:04.296119+00:00',
#  '2020-11-09 14:25:04.330280+00:00', '2020-11-09 14:25:04.376561+00:00',
#  '2020-11-09 14:25:04.406506+00:00', '2020-11-09 14:25:04.425003+00:00',
#  '2020-11-09 14:25:04.444449+00:00', '2020-11-09 14:25:04.462577+00:00',
# ...

# %% [markdown]
# ### all the dates are same hence there is no point of establishing relationship wrt date
